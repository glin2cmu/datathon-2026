# %% [markdown]
# # CMU Data Science Club Datathon 2026
#
# ---
#
#
#
# **Team Name:** andrewID of team member submitting (only 1 member submits for entire team)
#
# **Names:** include member submitting: team member 1, team member 2, team member 3, ...
#
# **Andrew IDs:** include member submitting: andrew id 1, andrew id 2, andrew id 3, ...
#
# **This notebook is only for reference to help your team download the data and get started. Using this notebook is not required.**
# **Cite external datasets used, if any: .**

# %%
### Load Some Common Packages ###
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob
import os

# %% [markdown]
# We provide datasets from the United Nations. You may use any number of the datasets, and we encourage you to find your own datasets either entirely or supplementarily. Refer to the dataset schemas - the column description tables in the instructions packet - to understand what information is contained in the datasets. Additionally, we have provided some guiding questions but feel free to go beyond those.

# %%
# !pip install gdown

# %%
# !gdown 15cX26m-Gz_5urG3juTU9A-fRdgO5x_mX -O ../data/project_targeting/ 
# !gdown 1P1BRPe-SqRnJohCF6L4SabPx4iI8BJ86 -O ../data/geo_mismatch/
# !unzip ../data/project_targeting/project_targeting_data.zip -d ../data/project_targeting/
# !unzip ../data/geo_mismatch/geo_mismatch_data.zip -d ../data/geo_mismatch/

# %%
### Load the Data ###

# Set this to the folder containing the data for the problem you are addressing
DATA_PATH = "../project_targeting/data/*.csv" 

csv_files = glob.glob(DATA_PATH)
dataframes = {}

for file in csv_files:
    name = os.path.splitext(os.path.basename(file))[0]
    dataframes[name] = pd.read_csv(file)

    print(f"Loaded: {name}")
    print(dataframes[name].columns)
# Out:
# Loaded: Data_ CERF Donor Contributions and Allocations - contributions
# Index(['activityDateType', 'contributionCode', 'contributionId', 'countryCode',
#        'donor', 'donorcommitment', 'donorpledge', 'donorreceived',
#        'donorwriteoff', 'latestDate', 'latestDateAsDate', 'flag', 'donortype',
#        'regionName', 'statusCode', 'year'],
#       dtype='object')
# Loaded: CERF Climate Related Allocations - CERF climate related allocations
# Index(['Year', 'CERF allocations for drought', 'CERF allocations for floods',
#        'CERF allocations for storms', 'CERF allocations for heat/cold waves',
#        'TOTAL climate related allocations ', 'TOTAL CERF allocations (USD)',
#        'Climate allocation %'],
#       dtype='object')
# Loaded: Data_ Country Based Pooled Funds (CBPF) - Contributions
# Index(['PooledFundId', 'PooledFundName', 'PooledFundCodeAbbrv',
#        'ContributionCode', 'FiscalYear', 'DonorName', 'DonorCode',
# ...

# %%
### Preprocess the data and/or Feature Engineer ###

# %% [markdown]
# Write some explanations for what your team did in this section. For instance, how did your team handle missing (Null/NaN) values? Which columns did you feel are most relevant and why?

# %%
### Perform EDA ###

# %% [markdown]
# Write some explanations for what your team did in this section. For instance, what did you learn from you EDA? Is the data skewed? If so, how did you handle that?

# %%
### Fit Model(s) ###

# %% [markdown]
# Write some explanations for what your team did in this section. For instance, what kind of model did you use? Why did you feel this approach was the best for this task?

# %%
### Model Justification###

# %% [markdown]
# Write some explanations for what your team did in this section. For instance, what kind of analysis justifies your team's use of your team's model? How did your model perform?

# %%
### Make and Interpret Predictions ###

# %% [markdown]
# Write some explanations for what your team did in this section. What did you learn from your predictions? What does this imply about beneficiary projects or overlooked pooled fund coverage? What actions do you propose we take from here?
